# %% [markdown]
# # Slicing

# %%
b=np.random.randint(10,20,(5,4))
b
# Out:
# array([[17, 15, 11, 11],
#        [18, 11, 11, 11],
#        [13, 16, 14, 15],
#        [14, 17, 14, 14],
#        [17, 12, 13, 13]], dtype=int32)

# %%
b[1:3]
# Out:
# array([[18, 11, 11, 11],
#        [13, 16, 14, 15]], dtype=int32)

# %%
b[1,3]
# Out:
# np.int32(11)

# %% [markdown]
# ## : will parse row or column
# ## , gives the specific output

# %% [markdown]
# # Numpy Operations

# %%
a=np.random.randint(10,20,10)

# %%
a
# Out:
# array([12, 10, 17, 14, 15, 17, 13, 16, 15, 19], dtype=int32)

# %%
arr2=np.random.randint(90,100,(10,10))

# %%
arr2
# Out:
# array([[99, 99, 98, 99, 91, 97, 95, 97, 91, 91],
#        [94, 96, 90, 90, 92, 93, 92, 95, 94, 97],
#        [99, 99, 92, 92, 92, 95, 98, 96, 91, 95],
#        [90, 91, 94, 99, 98, 96, 99, 92, 91, 94],
#        [91, 91, 90, 97, 90, 90, 90, 99, 99, 91],
#        [96, 97, 96, 93, 95, 94, 90, 98, 95, 97],
#        [91, 90, 95, 96, 98, 99, 99, 94, 96, 91],
#        [99, 95, 99, 96, 93, 97, 96, 98, 98, 99],
#        [99, 95, 93, 96, 96, 91, 94, 90, 97, 94],
#        [98, 94, 90, 95, 95, 97, 94, 93, 98, 98]], dtype=int32)

# %%
a[:4]
# Out:
# array([12, 10, 17, 14], dtype=int32)

# %%
arr2.max()
# Out:
# np.int32(99)

# %%
arr2.min()
# Out:
# np.int32(90)

# %%
arr2.mean()
# Out:
# np.float64(94.78)

# %%
arr2.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 arr2.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
from numpy import *

# %%
np.median(arr2)
# Out:
# np.float64(95.0)

# %%
# call/print row in a matrix
arr2[2]
# Out:
# array([99, 99, 92, 92, 92, 95, 98, 96, 91, 95], dtype=int32)

# %%
#call/print column in a matrix
arr2[:,6]
# Out:
# array([95, 92, 98, 99, 90, 90, 99, 96, 94, 94], dtype=int32)

# %%
arr2[:,-1]
# Out:
# array([91, 97, 95, 94, 91, 97, 91, 99, 94, 98], dtype=int32)

# %%
arr2[2:6,2:4]
# Out:
# array([[92, 92],
#        [94, 99],
#        [90, 97],
#        [96, 93]], dtype=int32)

# %% [markdown]
# # Masking

# %%
arr2[arr2>50]
# Out:
# array([99, 99, 98, 99, 91, 97, 95, 97, 91, 91, 94, 96, 90, 90, 92, 93, 92,
#        95, 94, 97, 99, 99, 92, 92, 92, 95, 98, 96, 91, 95, 90, 91, 94, 99,
#        98, 96, 99, 92, 91, 94, 91, 91, 90, 97, 90, 90, 90, 99, 99, 91, 96,
#        97, 96, 93, 95, 94, 90, 98, 95, 97, 91, 90, 95, 96, 98, 99, 99, 94,
#        96, 91, 99, 95, 99, 96, 93, 97, 96, 98, 98, 99, 99, 95, 93, 96, 96,
#        91, 94, 90, 97, 94, 98, 94, 90, 95, 95, 97, 94, 93, 98, 98],
#       dtype=int32)

# %%
arr2[arr2>=50]
# Out:
# array([99, 99, 98, 99, 91, 97, 95, 97, 91, 91, 94, 96, 90, 90, 92, 93, 92,
#        95, 94, 97, 99, 99, 92, 92, 92, 95, 98, 96, 91, 95, 90, 91, 94, 99,
#        98, 96, 99, 92, 91, 94, 91, 91, 90, 97, 90, 90, 90, 99, 99, 91, 96,
#        97, 96, 93, 95, 94, 90, 98, 95, 97, 91, 90, 95, 96, 98, 99, 99, 94,
#        96, 91, 99, 95, 99, 96, 93, 97, 96, 98, 98, 99, 99, 95, 93, 96, 96,
#        91, 94, 90, 97, 94, 98, 94, 90, 95, 95, 97, 94, 93, 98, 98],
#       dtype=int32)

# %%
arr2[arr2<50]
# Out:
# array([], dtype=int32)

# %%
arr2[arr2==50]
# Out:
# array([], dtype=int32)

# %%
arr2[arr2!=50]
# Out:
# array([99, 99, 98, 99, 91, 97, 95, 97, 91, 91, 94, 96, 90, 90, 92, 93, 92,
#        95, 94, 97, 99, 99, 92, 92, 92, 95, 98, 96, 91, 95, 90, 91, 94, 99,
#        98, 96, 99, 92, 91, 94, 91, 91, 90, 97, 90, 90, 90, 99, 99, 91, 96,
#        97, 96, 93, 95, 94, 90, 98, 95, 97, 91, 90, 95, 96, 98, 99, 99, 94,
#        96, 91, 99, 95, 99, 96, 93, 97, 96, 98, 98, 99, 99, 95, 93, 96, 96,
#        91, 94, 90, 97, 94, 98, 94, 90, 95, 95, 97, 94, 93, 98, 98],
#       dtype=int32)
