# %%
import nltk

paragraph="Artificial Intelligence (AI) is a broad field of computer science focused on creating machines that can perform tasks which normally require human intelligence, such as reasoning, decision-making, understanding language, and recognizing patterns. Machine Learning (ML) is a subset of AI that enables systems to learn from data and improve their performance without being explicitly programmed. Instead of following fixed rules, ML algorithms identify patterns in data and use them to make predictions or decisions. Together, AI and ML are transforming many industries by powering applications like recommendation systems, speech recognition, image analysis, chatbots, and predictive analytics. AI provides the overall goal of intelligent behavior, while ML supplies the data-driven techniques that make this intelligence practical and scalable in real-world applications."

# %%
paragraph
# Out:
# 'Artificial Intelligence (AI) is a broad field of computer science focused on creating machines that can perform tasks which normally require human intelligence, such as reasoning, decision-making, understanding language, and recognizing patterns. Machine Learning (ML) is a subset of AI that enables systems to learn from data and improve their performance without being explicitly programmed. Instead of following fixed rules, ML algorithms identify patterns in data and use them to make predictions or decisions. Together, AI and ML are transforming many industries by powering applications like recommendation systems, speech recognition, image analysis, chatbots, and predictive analytics. AI provides the overall goal of intelligent behavior, while ML supplies the data-driven techniques that make this intelligence practical and scalable in real-world applications.'

# %%
sentences =nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['Artificial Intelligence (AI) is a broad field of computer science focused on creating machines that can perform tasks which normally require human intelligence, such as reasoning, decision-making, understanding language, and recognizing patterns.',
#  'Machine Learning (ML) is a subset of AI that enables systems to learn from data and improve their performance without being explicitly programmed.',
#  'Instead of following fixed rules, ML algorithms identify patterns in data and use them to make predictions or decisions.',
#  'Together, AI and ML are transforming many industries by powering applications like recommendation systems, speech recognition, image analysis, chatbots, and predictive analytics.',
#  'AI provides the overall goal of intelligent behavior, while ML supplies the data-driven techniques that make this intelligence practical and scalable in real-world applications.']

# %%
words=nltk.word_tokenize(paragraph)

# %%
words
# Out:
# ['Artificial',
#  'Intelligence',
#  '(',
#  'AI',
#  ')',
#  'is',
#  'a',
#  'broad',
#  'field',
#  'of',
#  'computer',
#  'science',
#  'focused',
#  'on',
#  'creating',
#  'machines',
#  'that',
#  'can',
#  'perform',
#  'tasks',
#  'which',
#  'normally',
#  'require',
#  'human',
#  'intelligence',
#  ',',
#  'such',
#  'as',
#  'reasoning',
#  ',',
#  'decision-making',
#  ',',
#  'understanding',
#  'language',
#  ',',
#  'and',
#  'recognizing',
#  'patterns',
#  '.',
#  'Machine',
#  'Learning',
#  '(',
#  'ML',
#  ')',
#  'is',
#  'a',
#  'subset',
#  'of',
#  'AI',
#  'that',
#  'enables',
#  'systems',
#  'to',
#  'learn',
#  'from',
#  'data',
#  'and',
#  'improve',
#  'their',
#  'performance',
#  'without',
#  'being',
#  'explicitly',
#  'programmed',
#  '.',
#  'Instead',
#  'of',
#  'following',
#  'fixed',
#  'rules',
#  ',',
#  'ML',
#  'algorithms',
#  'identify',
#  'patterns',
#  'in',
#  'data',
#  'and',
#  'use',
#  'them',
#  'to',
#  'make',
# ...

# %%
len(words)
# Out:
# 140

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.corpus import stopwords

# %%
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['Artificial Intelligence (AI) is a broad field of computer science focused on creating machines that can perform tasks which normally require human intelligence, such as reasoning, decision-making, understanding language, and recognizing patterns.',
#  'Machine Learning (ML) is a subset of AI that enables systems to learn from data and improve their performance without being explicitly programmed.',
#  'Instead of following fixed rules, ML algorithms identify patterns in data and use them to make predictions or decisions.',
#  'Together, AI and ML are transforming many industries by powering applications like recommendation systems, speech recognition, image analysis, chatbots, and predictive analytics.',
#  'AI provides the overall goal of intelligent behavior, while ML supplies the data-driven techniques that make this intelligence practical and scalable in real-world applications.']

# %%
stemmer=PorterStemmer()

# %%
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i]=' '.join(words)

# %%
sentences
# Out:
# ['artificiintellig ( ai ) broadfieldcomputsciencfocuscreatmachinperformtasknormalrequirhumanintellig , reason , decision-mak , understandlanguag , recognpattern .',
#  'machinlearn ( ml ) subsetaienablsystemlearndataimprovperformwithoutexplicitliprogram .',
#  'insteadfollowfixrul , mlalgorithmidentifipatterndatausemakepredictdeci .',
#  'togeth , aimltransformmaniindustripowerappliclikerecommendsystem , speechrecognit , imaganalysi , chatbot , predictanalyt .',
#  'aiprovidoveralgoalintelligbehavior , mlsupplidata-driventechniqumakeintelligpracticscalablreal-worldappl .']
