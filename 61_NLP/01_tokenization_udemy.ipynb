# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\91995\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\91995\anaconda3\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\91995\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\91995\anaconda3\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\91995\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\91995\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus="""Hello Welcome,to Krish Naik NLP Tutorials.
Please do watch the entire course! to becoe expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Krish Naik NLP Tutorials.
# Please do watch the entire course! to becoe expert in NLP.

# %%
## Tokenization
### Paragraph to sentence
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ['Hello Welcome,to Krish Naik NLP Tutorials.',
#  'Please do watch the entire course!',
#  'to becoe expert in NLP.']

# %%
## Tokenization
## Paragraph to words
## Sentence to words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'becoe',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Krish', 'Naik', 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'becoe', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Krish',
#  'Naik',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'becoe',
#  'expert',
#  'in',
#  'NLP',
#  '.']
