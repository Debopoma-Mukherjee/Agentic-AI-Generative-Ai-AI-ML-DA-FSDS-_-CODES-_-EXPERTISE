# %%
paragraph="""Good morning everyone,

Today I want to talk about the importance of continuous learning.

We live in a world where technology changes rapidly. New tools, programming languages, and frameworks appear every year. What we know today may become outdated tomorrow. That is why learning should never stop.

As students and professionals, we often focus on completing exams, assignments, or projects. But true growth happens when we remain curious and keep improving our skills beyond what is required. Reading books, building projects, solving problems, and asking questions all help us become better every day.

In the field of technology, continuous learning is especially important. A person who learns consistently becomes more adaptable, confident, and capable of solving real-world problems. Whether it is machine learning, data engineering, cloud computing, or software development, success comes to those who are willing to learn and practice regularly.

Learning also teaches patience. At first, many concepts seem difficult and confusing. But with persistence and dedication, understanding gradually develops. Every expert was once a beginner who chose not to give up.

So let us make a commitment to learn something new each day. Even small progress, repeated over time, leads to remarkable results.

Thank you.
"""

# %%
import nltk
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['Good morning everyone,\n\nToday I want to talk about the importance of continuous learning.',
#  'We live in a world where technology changes rapidly.',
#  'New tools, programming languages, and frameworks appear every year.',
#  'What we know today may become outdated tomorrow.',
#  'That is why learning should never stop.',
#  'As students and professionals, we often focus on completing exams, assignments, or projects.',
#  'But true growth happens when we remain curious and keep improving our skills beyond what is required.',
#  'Reading books, building projects, solving problems, and asking questions all help us become better every day.',
#  'In the field of technology, continuous learning is especially important.',
#  'A person who learns consistently becomes more adaptable, confident, and capable of solving real-world problems.',
# ...

# %%
from nltk.corpus import stopwords
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentence[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('good', 'JJ'), ('morn', 'NN'), ('everyon', 'NN'), (',', ','), ('today', 'NN'), ('want', 'VBP'), ('talk', 'NN'), ('import', 'NN'), ('continu', 'NN'), ('learn', 'NN'), ('.', '.')]
# [('live', 'JJ'), ('world', 'NN'), ('technolog', 'NN'), ('chang', 'NN'), ('rapidli', 'NN'), ('.', '.')]
# [('new', 'JJ'), ('tool', 'NN'), (',', ','), ('program', 'NN'), ('languag', 'NN'), (',', ','), ('framework', 'NN'), ('appear', 'VBP'), ('everi', 'JJ'), ('year', 'NN'), ('.', '.')]
# [('know', 'NNS'), ('today', 'NN'), ('may', 'MD'), ('becom', 'VB'), ('outdat', 'NN'), ('tomorrow', 'NN'), ('.', '.')]
# [('learn', 'NN'), ('never', 'RB'), ('stop', 'VB'), ('.', '.')]
# [('student', 'NN'), ('profession', 'NN'), (',', ','), ('often', 'RB'), ('focu', 'JJ'), ('complet', 'NN'), ('exam', 'NN'), (',', ','), ('assign', 'NN'), (',', ','), ('project', 'NN'), ('.', '.')]
# ...

# %%
for i in "Taj Mahal is a beautiful Monument".split():
    print(nltk.pos_tag([i]))
# Out:
# [('Taj', 'NN')]
# [('Mahal', 'NN')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('beautiful', 'NN')]
# [('Monument', 'NN')]
