# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\91995\NIT\54_Project\student_info.csv")

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df.tail()
# Out:
#      study_hours  student_marks
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50

# %%
df.shape
# Out:
# (200, 2)

# %% [markdown]
# # Discover and visualize the data to gain insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    195 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %% [markdown]
# # Descriptive statistics

# %%
df.describe()
# Out:
#        study_hours  student_marks
# count   195.000000      200.00000
# mean      6.995949       77.93375
# std       1.253060        4.92570
# min       5.010000       68.57000
# 25%       5.775000       73.38500
# 50%       7.120000       77.71000
# 75%       8.085000       82.32000
# max       8.990000       86.99000

# %% [markdown]
# plt.scatter(x=df.study_hours,y=df.student_marks)
# plt.xlabel("Student study hours")
# plt.ylabel("Student marks")
# plt.title("Scatter Plot of Students Study Hours vs Student marks")
# plt.show()

# %% [markdown]
# # Data Cleaning

# %%
df
# Out:
#      study_hours  student_marks
# 0           6.83          78.50
# 1           6.56          76.74
# 2            NaN          78.68
# 3           5.67          71.82
# 4           8.67          84.19
# ..           ...            ...
# 195         7.53          81.67
# 196         8.56          84.68
# 197         8.94          86.75
# 198         6.60          78.05
# 199         8.35          83.50
#
# [200 rows x 2 columns]

# %%
df.mean()
# Out:
# study_hours       6.995949
# student_marks    77.933750
# dtype: float64

# %%
df2=df.fillna(df.mean())

# %%
df2
# Out:
#      study_hours  student_marks
# 0       6.830000          78.50
# 1       6.560000          76.74
# 2       6.995949          78.68
# 3       5.670000          71.82
# 4       8.670000          84.19
# ..           ...            ...
# 195     7.530000          81.67
# 196     8.560000          84.68
# 197     8.940000          86.75
# 198     6.600000          78.05
# 199     8.350000          83.50
#
# [200 rows x 2 columns]

# %%
df2.head()
# Out:
#    study_hours  student_marks
# 0     6.830000          78.50
# 1     6.560000          76.74
# 2     6.995949          78.68
# 3     5.670000          71.82
# 4     8.670000          84.19

# %%
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   study_hours    200 non-null    float64
#  1   student_marks  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
X=df2.drop("student_marks",axis="columns")
y=df2.drop("study_hours",axis="columns")
print("Shape of X=",X.shape)
print("Shape of y=",y.shape)
# Out:
# Shape of X= (200, 1)
# Shape of y= (200, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
print("shape of X_train=",X_train.shape)
print("shape of y_train=",y_train.shape)
print("shape of X_test=",X_test.shape)
print("shape of y_test=",y_test.shape)
# Out:
# shape of X_train= (160, 1)
# shape of y_train= (160, 1)
# shape of X_test= (40, 1)
# shape of y_test= (40, 1)

# %% [markdown]
# # Select a model and train it

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[3.93037294]])

# %%
lr.intercept_
# Out:
# array([50.45063632])

# %%
m=3.93
c=50.44
y=m*10+c
y
# Out:
# 89.74000000000001

# %%
m=3.93
c=50.44
y=m*11+c
y
# Out:
# 93.67

# %%
lr.predict([[11]]).round(2)
# Out:
# C:\Users\91995\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[93.68]])

# %%
y_predict=lr.predict(X_test)
y_predict
# Out:
# array([[83.50507271],
#        [70.84927186],
#        [72.93236952],
#        [85.35234799],
#        [73.20749562],
#        [84.48766595],
#        [80.12495199],
#        [81.85431608],
#        [80.91102657],
#        [82.20804964],
#        [78.98514384],
#        [84.84139951],
#        [77.84533568],
#        [77.68812077],
#        [83.22994661],
#        [85.78468901],
#        [84.9593107 ],
#        [72.61793968],
#        [78.71001773],
#        [79.18166248],
#        [84.2911473 ],
#        [85.6274741 ],
#        [74.74034107],
#        [81.3433676 ],
#        [72.02838374],
#        [80.40007809],
#        [78.98514384],
#        [82.09013845],
#        [77.94732382],
#        [82.24735337],
#        [75.44780819],
#        [84.60557713],
#        [71.63534645],
#        [75.48711192],
#        [70.29901965],
#        [78.98514384],
#        [75.32989701],
#        [84.52696967],
#        [74.07217767],
#        [71.4388278 ]])

# %% [markdown]
# # Fine-tune your model

# %%
lr
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.9521841793508595

# %%
lr.score(X_train,y_train)
# Out:
# 0.9584528455152638

# %%
plt.scatter(X_train,y_train)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_train,lr.predict(X_train),color="r")

# %% [markdown]
# # joblib is a pckg used for serialization and deserialization to create a pipeline between backend and frontend

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib 
joblib.dump(lr,"Desktop.pkl")
# Out:
# ['Desktop.pkl']

# %%
pwd
# Out:
# 'C:\\Users\\91995\\NIT\\54_Project'

# %%
model=joblib.load("Desktop.pkl")

# %%
pwd
# Out:
# 'C:\\Users\\91995\\NIT\\54_Project'

# %%
model
# Out:
# LinearRegression()

# %% [markdown]
# # Launch,monitor and main your system

# %%
__name__
# Out:
# '__main__'
