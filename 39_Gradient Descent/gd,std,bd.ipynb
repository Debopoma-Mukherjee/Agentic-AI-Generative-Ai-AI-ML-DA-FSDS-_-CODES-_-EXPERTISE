# %% [markdown]
# # Gradient dedcent is an optimization algorithm that finds best fit line for given training data set individual data points to reach global minima
# # by reduce cost function and increased accuracy.
# ## 1)step size in gradient descnd is called learning rate or momentum in gradient descent
# ## 2)learning rate always be minimum 0.01 or 0.001
# ### For big data gradient descent is slow.the reason we compute math individually.So we implement Stochastic and Batch Gradient Descent
#
# # Stochastic Gradient Descent
# ## it is an optimization technique to compute random cluster datapoint and take mean to reach global minima and increase accuracy.
# ## It is especially useful when there are redundancies in the data.
#
# # Batch Gradient Descent
# ## it is an optimization algorithm to compute batch wise cluster datapoint and take mean to reach global minima and increase accuracy.

# %%
# Regression
 ## Linear
    ### Simple linear regression
    ### Multiple Linear Regression
    ### l1 regression|lasso
    ### l2 regression|ridge
    ### gradient descend algo
    ### stocastic and batch gd algo
    ### Time Series
 ## Non linear 
    ### Polynomial
    ### SVM
    ### K nearest neighbour
    ### desicion tree regresssion
    ### random forest regression
    ### xgboost regression
    ### gbm regressor
