# %% [markdown]
# # Text To Speech using gtts

# %%
pip install gtts
# Out:
# Collecting gtts
#   Downloading gTTS-2.5.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\91995\anaconda3\lib\site-packages (from gtts) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in c:\users\91995\anaconda3\lib\site-packages (from gtts) (8.1.8)
# Requirement already satisfied: colorama in c:\users\91995\anaconda3\lib\site-packages (from click<8.2,>=7.1->gtts) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91995\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91995\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91995\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91995\anaconda3\lib\site-packages (from requests<3,>=2.27->gtts) (2025.4.26)
# Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Installing collected packages: gtts
# Successfully installed gtts-2.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython
# Out:
# Requirement already satisfied: ipython in c:\users\91995\appdata\roaming\python\python313\site-packages (9.6.0)
# Requirement already satisfied: colorama in c:\users\91995\anaconda3\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\91995\appdata\roaming\python\python313\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\91995\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\91995\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\91995\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\91995\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\91995\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech=gTTS('''welcome to this course''',lang='hi',tld='com')
text_to_speech.save('text_to_speech_gtts.wav')
sound_file='text_to_speech_gtts.wav'
Audio(sound_file,autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
