# %% [markdown]
# # Classification
# ## 1)Performance measure of regression--R2,adjusted R2
# ## 2)Performance measure of classification--Confusion matrix
# ### i)TP(True+ve)
# ### ii)FP(False+ve)|Type1
# ### iii)TN(True-ve)
# ### iv)FN(False -ve)|Type2

# %% [markdown]
# ## Model accuracy==(TN+TP)/(TN+TP+FN+FP)

# %% [markdown]
# ## Error=1-Accuracy
# ## Error= fp+fn/tp+tn+fp+fn

# %% [markdown]
# ## Precission=tp/predicted yes
# ## recall=tp/actual yes

# %% [markdown]
# ## F1 score=2*(precision*recall)/(precision+recall)

# %% [markdown]
# # 1)Logistic Regression

# %% [markdown]
# ### Logistic regression is classification.It is classification because Logistic Regression predicts a probability between 0 and 1.
# ### Output = 0.87 → 87% chance the class is 1
# ### Output = 0.12 → 12% chance the class is 1

# %% [markdown]
# # Sigmoid curve helps to include the outliers due to its shape

# %% [markdown]
# # Range of Sigmoid Curve is 0-1

# %% [markdown]
# # Logistic Regression also called as maxent classifier or logit classifier
