# %%
import numpy as np

# %%
import matplotlib.pyplot as plt #Visualization

# %%
from PIL import Image #python image library

# %%
image=Image.open(r'C:\Users\91995\Downloads\project_num.jpg') #Using r'' is recommended whenever we deal with Windows file paths or regular expressions, since both use backslashes frequently.

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x413>

# %%
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
peacock_arr=np.asarray(image)
peacock_arr
# Out:
# array([[[ 33,  33,  35],
#         [ 20,  20,  22],
#         [  8,   8,  10],
#         ...,
#         [226, 227, 231],
#         [226, 227, 231],
#         [226, 227, 231]],
#
#        [[ 25,  25,  27],
#         [ 16,  16,  18],
#         [  7,   7,   9],
#         ...,
#         [226, 227, 231],
#         [226, 227, 231],
#         [226, 227, 231]],
#
#        [[ 17,  17,  17],
#         [ 11,  11,  11],
#         [  8,   8,   8],
#         ...,
#         [226, 227, 231],
#         [226, 227, 231],
#         [226, 227, 231]],
#
#        ...,
#
#        [[145, 117, 103],
#         [153, 127, 112],
#         [163, 137, 124],
#         ...,
#         [  1,  21,  19],
#         [  1,  23,  20],
#         [  1,  24,  18]],
#
#        [[152, 124, 112],
#         [163, 135, 123],
#         [175, 147, 135],
#         ...,
#         [  1,  16,  13],
#         [  1,  17,  14],
#         [  0,  18,  12]],
#
#        [[154, 126, 115],
#         [166, 138, 127],
#         [179, 151, 140],
# ...

# %%
plt.imshow(peacock_arr)
plt.show()

# %%
peacock_arr.shape
# Out:
# (413, 236, 3)

# %% [markdown]
# # We use numpy when we work with cpu which leads to slower development
# # We use torch tensors when we work with GPU for faster development when we are creating high level models
